# %% [markdown]
# <a href="https://colab.research.google.com/github/QaziSaim/Fine-Tune-Projects/blob/main/fine_tune_misteral_7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub

# %%
import kagglehub
kagglehub.login()
# Out:
# ...
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
import kagglehub

# Download latest version
path = kagglehub.model_download("mistral-ai/mistral/pyTorch/7b-instruct-v0.1-hf")

print("Path to model files:", path)
# Out:
# ...
# 100%|██████████| 1.48k/1.48k [00:00<00:00, 2.03MB/s]
# ...
#   0%|          | 0.00/72.0 [00:00<?, ?B/s]
#
# 100%|██████████| 72.0/72.0 [00:00<00:00, 22.3kB/s]
#
# 100%|██████████| 116/116 [00:00<00:00, 144kB/s]
# 100%|██████████| 23.4k/23.4k [00:00<00:00, 2.94MB/s]
# ...
#   0%|          | 0.00/1.71M [00:00<?, ?B/s]
# ...
#   0%|          | 0.00/571 [00:00<?, ?B/s]
#
#
# 100%|██████████| 571/571 [00:00<00:00, 227kB/s]
# ...
#   0%|          | 0.00/9.26G [00:00<?, ?B/s]
# 100%|██████████| 1.71M/1.71M [00:00<00:00, 8.24MB/s]
# ...
#   0%|          | 0.00/482k [00:00<?, ?B/s]
#
#
#   0%|          | 1.00M/4.72G [00:00<16:13, 5.20MB/s]
#
#   0%|          | 1.00M/9.26G [00:00<30:59, 5.35MB/s]
# ...
# 100%|██████████| 1.43k/1.43k [00:00<00:00, 4.61MB/s]
#
#
#
#   0%|          | 7.00M/4.72G [00:00<02:54, 29.1MB/s]
#
#   0%|          | 8.00M/9.26G [00:00<04:58, 33.3MB/s]
# 100%|██████████| 482k/482k [00:00<00:00, 3.08MB/s]
#
#
#   0%|          | 15.0M/9.26G [00:00<03:41, 44.9MB/s]
#
#
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "/root/.cache/kagglehub/models/mistral-ai/mistral/pyTorch/7b-instruct-v0.1-hf/1"  # or your downloaded path if local

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",       # puts model on GPU if available
    torch_dtype="auto"       # use fp16/bf16 automatically if supported
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device_map="auto")

prompt = "Once upon a time in the world of AI,"
out = pipe(prompt, max_new_tokens=50, do_sample=True, temperature=0.7, top_p=0.9)

print(out[0]["generated_text"])
# Out:
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Once upon a time in the world of AI, there was a debate about whether machines could ever truly understand the meaning of words. Some argued that machines, no matter how advanced, could never truly grasp the nuances and complexities of human language. Others believed that with the right programming and enough data
